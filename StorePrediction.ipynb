# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
import numpy as np

# %% [markdown]
# # Section 1: Data Loading

# %%
def load_data(train_path, test_path):
    train_data = pd.read_csv(train_path, encoding='ISO-8859-1')
    test_data = pd.read_csv(test_path, encoding='ISO-8859-1')
    return train_data, test_data

# %%
train_path = 'store_train.csv'
test_path = 'store_test.csv'
output_path = 'store_predictions.csv'

# Load the data
train_data, test_data = load_data(train_path, test_path)

# %%
train_data.head()
# Out:
#            Id  sales0  sales1  sales2  sales3  sales4  country  State  CouSub  \
# 0  2300919770     848     588     666    1116    1133        9     23   19770
# 1  5000129575     925     717     780    1283    1550        1     50   29575
# 2  2501308470     924     616     739    1154    1314       13     25    8470
# 3   603599999     924     646     683    1292    1297       35      6   99999
# 4  5002760100    1017     730     735    1208    1326       27     50   60100
#
#        countyname         storecode                            Areaname  \
# 0  Hancock County  NCNTY23009N23009                  Hancock County, ME
# 1  Addison County  NCNTY50001N50001                  Addison County, VT
# 2  Hampden County  METRO44140M44140  Springfield, MA HUD Metro FMR Area
# 3   Lassen County  NCNTY06035N06035                   Lassen County, CA
# 4  Windsor County  NCNTY50027N50027                  Windsor County, VT
#
#    countytownname  population state_alpha         store_Type  store
# 0  Eastbrook town       423.0          ME  Supermarket Type1      0
# 1  Granville town       298.0          VT  Supermarket Type1      0
# 2  Brimfield town      3609.0          MA  Supermarket Type1      1
# 3   Lassen County     34895.0          CA  Supermarket Type3      0
# 4  Rochester town      1139.0          VT  Supermarket Type1      0

# %%
test_data.head()
# Out:
#           Id  sales0  sales1  sales2  sales3  sales4  country  State  CouSub  \
# 0  101799999     696     511     514     867    1034     17.0      1   99999
# 1  101999999     599     481     500     883     894     19.0      1   99999
# 2  102199999     599     423     475     802    1061     21.0      1   99999
# 3  103599999     599     459     462     883     886     35.0      1   99999
# 4  103799999     599     481     505     746     801     37.0      1   99999
#
#         countyname         storecode                               Areaname  \
# 0  Chambers County  NCNTY01017N01017                    Chambers County, AL
# 1  Cherokee County  NCNTY01019N01019                    Cherokee County, AL
# 2   Chilton County  METRO13820N01021  Chilton County, AL HUD Metro FMR Area
# 3   Conecuh County  NCNTY01035N01035                     Conecuh County, AL
# 4     Coosa County  NCNTY01037N01037                       Coosa County, AL
#
#     countytownname  population state_alpha         store_Type
# 0  Chambers County     34215.0          AL  Supermarket Type1
# 1  Cherokee County     25989.0          AL  Supermarket Type1
# 2   Chilton County     43643.0          AL  Supermarket Type1
# 3   Conecuh County     13228.0          AL  Supermarket Type1
# 4     Coosa County     11539.0          AL  Supermarket Type3

# %% [markdown]
# # Section 2: Data Preprocessing

# %%
def preprocess_data(train_data, test_data):
    # Drop unnecessary columns
    train_data = train_data.drop(columns=['Id', 'State', 'Areaname', 'countytownname'])
    test_ids = test_data['Id']
    test_data = test_data.drop(columns=['Id', 'State', 'Areaname', 'countytownname'])

    # Separate features and target variable from training data
    X = train_data.drop(columns=['store'])
    y = train_data['store']

    # Convert countries to category type
    X['country'] = X['country'].astype('category')
    test_data['country'] = test_data['country'].astype('category')

    # Replace 99999 with NaN in CouSub
    X['CouSub'] = X['CouSub'].replace(99999, np.nan)
    test_data['CouSub'] = test_data['CouSub'].replace(99999, np.nan)

    # Feature engineering for 'storecode'
    X['storecode_alphabets'] = X['storecode'].apply(lambda x: ''.join(filter(str.isalpha, str(x))))
    test_data['storecode_alphabets'] = test_data['storecode'].apply(lambda x: ''.join(filter(str.isalpha, str(x))))

    # Drop the original 'storecode' as it should not be used as is
    X = X.drop(columns=['storecode'])
    test_data = test_data.drop(columns=['storecode'])

    # Impute missing values for population and replace population values less than 100 with NaN
    X['population'] = X['population'].apply(lambda x: np.nan if x < 100 else x)
    test_data['population'] = test_data['population'].apply(lambda x: np.nan if x < 100 else x)

    # Impute missing values for population using median strategy
    imputer = SimpleImputer(strategy='median')
    X['population'] = imputer.fit_transform(X[['population']])
    test_data['population'] = imputer.transform(test_data[['population']])
    X['CouSub'] = imputer.fit_transform(X[['CouSub']])
    test_data['CouSub'] = imputer.transform(test_data[['CouSub']])

    # Combine train and test data for consistent preprocessing
    combined_data = pd.concat([X, test_data], keys=['train', 'test'])

    # One-hot encode categorical variables
    categorical_cols = combined_data.select_dtypes(include=['object', 'category']).columns
    combined_data = pd.get_dummies(combined_data, columns=categorical_cols)

    # Split combined data back into train and test sets
    X = combined_data.xs('train')
    test_data = combined_data.xs('test')

    return X, y, test_data, test_ids

# %%
X, y, test_data, test_ids = preprocess_data(train_data, test_data)

# %%
X.head()
# Out:
#    sales0  sales1  sales2  sales3  sales4  country   CouSub  population  \
# 0     848     588     666    1116    1133      9.0  19770.0       423.0
# 1     925     717     780    1283    1550      1.0  29575.0       298.0
# 2     924     616     739    1154    1314     13.0   8470.0      3609.0
# 3     924     646     683    1292    1297     35.0  42460.0     34895.0
# 4    1017     730     735    1208    1326     27.0  60100.0      1139.0
#
#    countyname_Abbeville County  countyname_Acadia Parish  ...  state_alpha_WV  \
# 0                        False                     False  ...           False
# 1                        False                     False  ...           False
# 2                        False                     False  ...           False
# 3                        False                     False  ...           False
# 4                        False                     False  ...           False
#
#    state_alpha_WY  store_Type_Grocery Store  store_Type_Supermarket Type1  \
# 0           False                     False                          True
# 1           False                     False                          True
# 2           False                     False                          True
# 3           False                     False                         False
# 4           False                     False                          True
#
#    store_Type_Supermarket Type2  store_Type_Supermarket Type3  \
# 0                         False                         False
# 1                         False                         False
# 2                         False                         False
# 3                         False                          True
# 4                         False                         False
#
#    storecode_alphabets_METROM  storecode_alphabets_METROMM  \
# 0                       False                        False
# 1                       False                        False
# 2                        True                        False
# 3                       False                        False
# 4                       False                        False
#
#    storecode_alphabets_METRON  storecode_alphabets_NCNTYN
# 0                       False                        True
# 1                       False                        True
# 2                       False                       False
# 3                       False                        True
# 4                       False                        True
#
# [5 rows x 2032 columns]

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0
# Name: store, dtype: int64

# %%
test_data.head()
# Out:
#    sales0  sales1  sales2  sales3  sales4  country   CouSub  population  \
# 0     696     511     514     867    1034     17.0  42460.0     34215.0
# 1     599     481     500     883     894     19.0  42460.0     25989.0
# 2     599     423     475     802    1061     21.0  42460.0     43643.0
# 3     599     459     462     883     886     35.0  42460.0     13228.0
# 4     599     481     505     746     801     37.0  42460.0     11539.0
#
#    countyname_Abbeville County  countyname_Acadia Parish  ...  state_alpha_WV  \
# 0                        False                     False  ...           False
# 1                        False                     False  ...           False
# 2                        False                     False  ...           False
# 3                        False                     False  ...           False
# 4                        False                     False  ...           False
#
#    state_alpha_WY  store_Type_Grocery Store  store_Type_Supermarket Type1  \
# 0           False                     False                          True
# 1           False                     False                          True
# 2           False                     False                          True
# 3           False                     False                          True
# 4           False                     False                         False
#
#    store_Type_Supermarket Type2  store_Type_Supermarket Type3  \
# 0                         False                         False
# 1                         False                         False
# 2                         False                         False
# 3                         False                         False
# 4                         False                          True
#
#    storecode_alphabets_METROM  storecode_alphabets_METROMM  \
# 0                       False                        False
# 1                       False                        False
# 2                       False                        False
# 3                       False                        False
# 4                       False                        False
#
#    storecode_alphabets_METRON  storecode_alphabets_NCNTYN
# 0                       False                        True
# 1                       False                        True
# 2                        True                       False
# 3                       False                        True
# 4                       False                        True
#
# [5 rows x 2032 columns]

# %%
test_ids.head()
# Out:
# 0    101799999
# 1    101999999
# 2    102199999
# 3    103599999
# 4    103799999
# Name: Id, dtype: int64

# %% [markdown]
# # Section 3: Train-Validation Split

# %%
def split_data(X, y, test_size=0.2, random_state=42):
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=test_size, random_state=random_state)
    return X_train, X_val, y_train, y_val

# %%
X_train, X_val, y_train, y_val = split_data(X, y)

# %%
X_train.head()
# Out:
#       sales0  sales1  sales2  sales3  sales4  country   CouSub  population  \
# 1117     847     504     672    1055    1132     15.0  48645.0      1752.0
# 3102     922     743     748    1182    1232     13.0  51620.0       355.0
# 2707     604     399     448     890     893      5.0  42460.0      5685.0
# 1102     772     567     571     961    1169    263.0  42460.0      6865.0
# 2181     631     419     466     878     881    107.0  42460.0     30305.0
#
#       countyname_Abbeville County  countyname_Acadia Parish  ...  \
# 1117                        False                     False  ...
# 3102                        False                     False  ...
# 2707                        False                     False  ...
# 1102                        False                     False  ...
# 2181                        False                     False  ...
#
#       state_alpha_WV  state_alpha_WY  store_Type_Grocery Store  \
# 1117           False           False                     False
# 3102           False           False                      True
# 2707           False           False                     False
# 1102           False           False                     False
# 2181           False           False                     False
#
#       store_Type_Supermarket Type1  store_Type_Supermarket Type2  \
# 1117                          True                         False
# 3102                         False                         False
# 2707                          True                         False
# 1102                          True                         False
# 2181                         False                         False
#
#       store_Type_Supermarket Type3  storecode_alphabets_METROM  \
# 1117                         False                       False
# 3102                         False                       False
# 2707                         False                       False
# 1102                         False                       False
# 2181                          True                       False
#
#       storecode_alphabets_METROMM  storecode_alphabets_METRON  \
# 1117                        False                       False
# 3102                        False                       False
# 2707                        False                       False
# 1102                        False                       False
# 2181                        False                       False
#
#       storecode_alphabets_NCNTYN
# 1117                        True
# 3102                        True
# 2707                        True
# 1102                        True
# 2181                        True
#
# [5 rows x 2032 columns]

# %%
X_val.head()
# Out:
#       sales0  sales1  sales2  sales3  sales4  country   CouSub  population  \
# 1706     593     402     450     788     792     93.0  42460.0      7089.0
# 3096     643     383     475     876    1139     51.0  42460.0      5916.0
# 729      586     473     494     805     967     11.0  42460.0     18395.0
# 3142     714     551     561     946    1062     43.0  42460.0     64519.0
# 997      927     678     732    1199    1461     11.0  51265.0      7839.0
#
#       countyname_Abbeville County  countyname_Acadia Parish  ...  \
# 1706                        False                     False  ...
# 3096                        False                     False  ...
# 729                         False                     False  ...
# 3142                        False                     False  ...
# 997                         False                     False  ...
#
#       state_alpha_WV  state_alpha_WY  store_Type_Grocery Store  \
# 1706           False           False                     False
# 3096           False           False                     False
# 729            False           False                     False
# 3142           False           False                     False
# 997            False           False                     False
#
#       store_Type_Supermarket Type1  store_Type_Supermarket Type2  \
# 1706                          True                         False
# 3096                          True                         False
# 729                           True                         False
# 3142                          True                         False
# 997                           True                         False
#
#       store_Type_Supermarket Type3  storecode_alphabets_METROM  \
# 1706                         False                       False
# 3096                         False                       False
# 729                          False                       False
# 3142                         False                        True
# 997                          False                       False
#
#       storecode_alphabets_METROMM  storecode_alphabets_METRON  \
# 1706                        False                       False
# 3096                        False                       False
# 729                         False                       False
# 3142                        False                       False
# 997                         False                        True
#
#       storecode_alphabets_NCNTYN
# 1706                        True
# 3096                        True
# 729                         True
# 3142                       False
# 997                        False
#
# [5 rows x 2032 columns]

# %%
y_train.head()
# Out:
# 1117    0
# 3102    0
# 2707    1
# 1102    0
# 2181    0
# Name: store, dtype: int64

# %%
y_val.head()
# Out:
# 1706    0
# 3096    0
# 729     0
# 3142    1
# 997     0
# Name: store, dtype: int64

# %% [markdown]
# # Section 4: Model Training Pipeline

# %%
def train_model(X_train, y_train):
    rf_model = RandomForestClassifier(random_state=42)

    # Hyperparameter tuning using GridSearchCV
    param_grid = {
        'n_estimators': [100, 200, 300],
        'max_depth': [10, 20, 30, None],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4]
    }

    grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid,
                               cv=3, n_jobs=-1, scoring='roc_auc')
    grid_search.fit(X_train, y_train)

    return grid_search.best_estimator_

# %%
rf_model = train_model(X_train, y_train)

# %% [markdown]
# # Section 5: Model Evaluation

# %%
def evaluate_model(model, X_val, y_val):
    val_probs = model.predict_proba(X_val)[:, 1]
    auc_score = roc_auc_score(y_val, val_probs)
    return auc_score

# %%
auc_score = evaluate_model(rf_model, X_val, y_val)
print(f'AUC Score on Validation Set: {auc_score}')
# Out:
# AUC Score on Validation Set: 0.8266792385057471

# %% [markdown]
# # Section 6: Predicting Test Data

# %%
def predict_test_data(model, test_data):
    test_probs = model.predict_proba(test_data)[:, 1]
    return test_probs

# %%
test_data.fillna(0, inplace=True)

# %%
test_probs = predict_test_data(rf_model, test_data)

# %%
test_probs
# Out:
# array([0.08058475, 0.13328203, 0.85441503, ..., 0.16563669, 0.05489416,
#        0.06752917])

# %%
assert not pd.isnull(test_probs).any(), "There are NA values in the predictions."

# %% [markdown]
# # Section 7: Saving Predictions

# %%
def save_predictions(predictions, test_ids, output_path):
    output = pd.DataFrame({'Id': test_ids, 'store': predictions})
    output.to_csv(output_path, index=False)
    print(f"Predictions have been saved to {output_path}")

# %%
save_predictions(test_probs, test_ids, output_path)
# Out:
# Predictions have been saved to store_predictions.csv
